# %%
cd CSV\ files
# Out:
# [Errno 2] No such file or directory: 'CSV files'
# /Users/sandrawelbeck/Desktop/Phase_1_Project_Folder/Microsoft_Movie_Project/Microsoft_Movie_Project/CSV files

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("combined_movie_data.csv")

# %%
df['movie_year'] = df.release_date_x.str[:4]
df.head()
# Out:
#    Unnamed: 0    titleId  start_year            genres  ordering  \
# 0           0  tt0069049      2018.0             Drama       3.0
# 1           1  tt0112502      2017.0   Horror,Thriller       3.0
# 2           2  tt4503112      2018.0     Action,Horror       3.0
# 3           3  tt9181914      2018.0  Animation,Family       5.0
# 4           4  tt0192528      2018.0             Drama       1.0
#
#                         title region      genre_ids    id_x  popularity  \
# 0  The Other Side of the Wind     US       [35, 18]  299782       9.800
# 1                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 2                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 3                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 4               Heaven & Hell     US           [18]  567662       0.600
#
#   release_date_x  vote_average  vote_count  id_y release_date_y  \
# 0     2018-11-02           7.0          64   NaN            NaN
# 1     2012-06-30           2.9          26   NaN            NaN
# 2     2012-06-30           2.9          26   NaN            NaN
# 3     2012-06-30           2.9          26   NaN            NaN
# 4     2018-11-06           7.5           2   NaN            NaN
#
#   production_budget domestic_gross worldwide_gross movie_year
# 0               NaN            NaN             NaN       2018
# 1               NaN            NaN             NaN       2012
# 2               NaN            NaN             NaN       2012
# 3               NaN            NaN             NaN       2012
# 4               NaN            NaN             NaN       2018

# %%
df.drop(df.loc[df['domestic_gross']=='$0'].index, inplace=True)

# %%
df1 = df.drop(['Unnamed: 0', 'start_year','titleId','worldwide_gross','genre_ids', 'id_x', 'worldwide_gross','id_y','ordering'], axis=1, inplace=False)

# %%
df1.head()
# Out:
#              genres                       title region  popularity  \
# 0             Drama  The Other Side of the Wind     US       9.800
# 1   Horror,Thriller                     Bigfoot     US       2.813
# 2     Action,Horror                     Bigfoot     US       2.813
# 3  Animation,Family                     Bigfoot     US       2.813
# 4             Drama               Heaven & Hell     US       0.600
#
#   release_date_x  vote_average  vote_count release_date_y production_budget  \
# 0     2018-11-02           7.0          64            NaN               NaN
# 1     2012-06-30           2.9          26            NaN               NaN
# 2     2012-06-30           2.9          26            NaN               NaN
# 3     2012-06-30           2.9          26            NaN               NaN
# 4     2018-11-06           7.5           2            NaN               NaN
#
#   domestic_gross movie_year
# 0            NaN       2018
# 1            NaN       2012
# 2            NaN       2012
# 3            NaN       2012
# 4            NaN       2018

# %%
df1.isnull().sum()
# Out:
# genres                   0
# title                    0
# region               10202
# popularity               0
# release_date_x           0
# vote_average             0
# vote_count               0
# release_date_y       23295
# production_budget    23295
# domestic_gross       23295
# movie_year               0
# dtype: int64

# %%
df2 = df1.dropna(axis = 0, subset = ['release_date_y', 'production_budget', 'domestic_gross'], inplace = False)
df2
# Out:
#                         genres          title region  popularity  \
# 22                    no genre  The Overnight     US       6.576
# 23              Comedy,Mystery  The Overnight     US       6.576
# 26     Adventure,Drama,Romance    On the Road     US       8.919
# 27                      Horror       Whiplash     US       6.298
# 28                 Drama,Music       Whiplash     US       6.298
# ...                        ...            ...    ...         ...
# 26098                 no genre    Man on Fire    NaN       1.790
# 26200                 no genre          Spawn    NaN       1.400
# 26317                 no genre         Enough    NaN       0.719
# 26457                 no genre   Undiscovered    NaN       0.600
# 26546                 no genre           Jaws    NaN       0.600
#
#       release_date_x  vote_average  vote_count release_date_y  \
# 22        2015-06-19           6.0         200   Jun 19, 2015
# 23        2015-06-19           6.0         200   Jun 19, 2015
# 26        2012-12-21           5.6         518   Mar 22, 2013
# 27        2013-01-18           7.9          94   Oct 10, 2014
# 28        2013-01-18           7.9          94   Oct 10, 2014
# ...              ...           ...         ...            ...
# 26098     2018-01-24           8.0           1   Apr 23, 2004
# 26200     2018-04-13          10.0           1   Jul 31, 1997
# 26317     2018-03-22           8.7           3   May 24, 2002
# 26457     2018-04-07           8.0           1   Aug 26, 2005
# 26546     2018-05-29           0.0           1   Jun 20, 1975
#
#       production_budget domestic_gross movie_year
# 22             $200,000     $1,109,808       2015
# 23             $200,000     $1,109,808       2015
# 26          $25,000,000       $720,828       2012
# 27           $3,300,000    $13,092,006       2013
# 28           $3,300,000    $13,092,006       2013
# ...                 ...            ...        ...
# 26098       $60,000,000    $77,906,816       2018
# 26200       $40,000,000    $54,979,992       2018
# 26317       $38,000,000    $39,177,215       2018
# 26457        $9,000,000     $1,069,318       2018
# 26546       $12,000,000   $260,000,000       2018
#
# [2793 rows x 11 columns]

# %%
df2.shape
# Out:
# (2793, 11)

# %%
df2.isnull().sum()
# Out:
# genres                 0
# title                  0
# region               168
# popularity             0
# release_date_x         0
# vote_average           0
# vote_count             0
# release_date_y         0
# production_budget      0
# domestic_gross         0
# movie_year             0
# dtype: int64

# %%
df2.dtypes
# Out:
# genres                object
# title                 object
# region                object
# popularity           float64
# release_date_x        object
# vote_average         float64
# vote_count             int64
# release_date_y        object
# production_budget     object
# domestic_gross        object
# movie_year            object
# dtype: object

# %%
df2['domestic_gross'] = df2['domestic_gross'].str.replace('$', '')
df2['domestic_gross'] = df2['domestic_gross'].str.replace(',', '')
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2['production_budget'] = df2['production_budget'].str.replace('$', '')
df2['production_budget'] = df2['production_budget'].str.replace(',', '')
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.dtypes
# Out:
# genres                object
# title                 object
# region                object
# popularity           float64
# release_date_x        object
# vote_average         float64
# vote_count             int64
# release_date_y        object
# production_budget     object
# domestic_gross        object
# movie_year            object
# dtype: object

# %%
df2['domestic_gross'] = pd.to_numeric(df2['domestic_gross'],errors='coerce')
df2['production_budget'] = pd.to_numeric(df2['production_budget'],errors='coerce')
#df2.loc[:,'domestic_gross'] = pd.to_numeric(df2.loc['domestic_gross'],errors='coerce')
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.dtypes
# Out:
# genres                object
# title                 object
# region                object
# popularity           float64
# release_date_x        object
# vote_average         float64
# vote_count             int64
# release_date_y        object
# production_budget      int64
# domestic_gross         int64
# movie_year            object
# dtype: object

# %%
# df2['ROI'] = ((df2['domestic_gross'] - df2['production_budget'])/df['domestic_gross'])*100
df2["net"] = df2['domestic_gross'] - df2['production_budget']
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.head()
# Out:
#                      genres          title region  popularity release_date_x  \
# 22                 no genre  The Overnight     US       6.576     2015-06-19
# 23           Comedy,Mystery  The Overnight     US       6.576     2015-06-19
# 26  Adventure,Drama,Romance    On the Road     US       8.919     2012-12-21
# 27                   Horror       Whiplash     US       6.298     2013-01-18
# 28              Drama,Music       Whiplash     US       6.298     2013-01-18
#
#     vote_average  vote_count release_date_y  production_budget  \
# 22           6.0         200   Jun 19, 2015             200000
# 23           6.0         200   Jun 19, 2015             200000
# 26           5.6         518   Mar 22, 2013           25000000
# 27           7.9          94   Oct 10, 2014            3300000
# 28           7.9          94   Oct 10, 2014            3300000
#
#     domestic_gross movie_year       net
# 22         1109808       2015    909808
# 23         1109808       2015    909808
# 26          720828       2012 -24279172
# 27        13092006       2013   9792006
# 28        13092006       2013   9792006

# %%
df2.drop(df2.loc[df2['genres']=='no genre'].index, inplace=True)
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df2.head()
# Out:
#                      genres          title region  popularity release_date_x  \
# 23           Comedy,Mystery  The Overnight     US       6.576     2015-06-19
# 26  Adventure,Drama,Romance    On the Road     US       8.919     2012-12-21
# 27                   Horror       Whiplash     US       6.298     2013-01-18
# 28              Drama,Music       Whiplash     US       6.298     2013-01-18
# 29                   Horror       Whiplash     US      28.784     2014-10-10
#
#     vote_average  vote_count release_date_y  production_budget  \
# 23           6.0         200   Jun 19, 2015             200000
# 26           5.6         518   Mar 22, 2013           25000000
# 27           7.9          94   Oct 10, 2014            3300000
# 28           7.9          94   Oct 10, 2014            3300000
# 29           8.4        7908   Oct 10, 2014            3300000
#
#     domestic_gross movie_year       net
# 23         1109808       2015    909808
# 26          720828       2012 -24279172
# 27        13092006       2013   9792006
# 28        13092006       2013   9792006
# 29        13092006       2014   9792006

# %%
df2['ROI'] = (df2['net']/df2['domestic_gross'])*100
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#                      genres          title region  popularity release_date_x  \
# 23           Comedy,Mystery  The Overnight     US       6.576     2015-06-19
# 26  Adventure,Drama,Romance    On the Road     US       8.919     2012-12-21
# 27                   Horror       Whiplash     US       6.298     2013-01-18
# 28              Drama,Music       Whiplash     US       6.298     2013-01-18
# 29                   Horror       Whiplash     US      28.784     2014-10-10
#
#     vote_average  vote_count release_date_y  production_budget  \
# 23           6.0         200   Jun 19, 2015             200000
# 26           5.6         518   Mar 22, 2013           25000000
# 27           7.9          94   Oct 10, 2014            3300000
# 28           7.9          94   Oct 10, 2014            3300000
# 29           8.4        7908   Oct 10, 2014            3300000
#
#     domestic_gross movie_year       net          ROI
# 23         1109808       2015    909808    81.978865
# 26          720828       2012 -24279172 -3368.233753
# 27        13092006       2013   9792006    74.793779
# 28        13092006       2013   9792006    74.793779
# 29        13092006       2014   9792006    74.793779

# %%
df2['ROI'].apply(np.ceil)
# Out:
# 23         82.0
# 26      -3368.0
# 27         75.0
# 28         75.0
# 29         75.0
#           ...
# 15926    -475.0
# 16018      78.0
# 16202      22.0
# 16260      86.0
# 16261      86.0
# Name: ROI, Length: 2620, dtype: float64

# %%
df2
# Out:
#                         genres            title region  popularity  \
# 23              Comedy,Mystery    The Overnight     US       6.576
# 26     Adventure,Drama,Romance      On the Road     US       8.919
# 27                      Horror         Whiplash     US       6.298
# 28                 Drama,Music         Whiplash     US       6.298
# 29                      Horror         Whiplash     US      28.784
# ...                        ...              ...    ...         ...
# 15926              Documentary            Teeth     US       0.600
# 16018     Drama,Horror,Mystery       Hereditary     US      26.185
# 16202              Documentary  Fahrenheit 11/9     US      10.003
# 16260      Comedy,Drama,Family          Monster     US       0.600
# 16261      Comedy,Drama,Family          Monster     US       0.600
#
#       release_date_x  vote_average  vote_count release_date_y  \
# 23        2015-06-19           6.0         200   Jun 19, 2015
# 26        2012-12-21           5.6         518   Mar 22, 2013
# 27        2013-01-18           7.9          94   Oct 10, 2014
# 28        2013-01-18           7.9          94   Oct 10, 2014
# 29        2014-10-10           8.4        7908   Oct 10, 2014
# ...              ...           ...         ...            ...
# 15926     2015-09-26           5.0           1   Jan 18, 2008
# 16018     2018-06-08           7.0        2491    Jun 8, 2018
# 16202     2018-09-10           7.1         142   Sep 21, 2018
# 16260     2010-01-01           5.0           1   Dec 24, 2003
# 16261     2012-09-10           7.0           1   Dec 24, 2003
#
#        production_budget  domestic_gross movie_year       net          ROI
# 23                200000         1109808       2015    909808    81.978865
# 26              25000000          720828       2012 -24279172 -3368.233753
# 27               3300000        13092006       2013   9792006    74.793779
# 28               3300000        13092006       2013   9792006    74.793779
# 29               3300000        13092006       2014   9792006    74.793779
# ...                  ...             ...        ...       ...          ...
# 15926            2000000          347578       2015  -1652422  -475.410411
# 16018           10000000        44069456       2018  34069456    77.308547
# 16202            5000000         6352306       2018   1352306    21.288427
# 16260            5000000        34469210       2010  29469210    85.494301
# 16261            5000000        34469210       2012  29469210    85.494301
#
# [2620 rows x 13 columns]

# %%
final_df = df2.drop_duplicates(subset=['title'])

# %%
final_df.tail()
# Out:
#                      genres            title region  popularity  \
# 15870    Action,Crime,Drama              War     US       0.600
# 15923                 Drama            Teeth     US       1.000
# 16018  Drama,Horror,Mystery       Hereditary     US      26.185
# 16202           Documentary  Fahrenheit 11/9     US      10.003
# 16260   Comedy,Drama,Family          Monster     US       0.600
#
#       release_date_x  vote_average  vote_count release_date_y  \
# 15870     2017-02-26           6.0           1   Aug 24, 2007
# 15923     2015-01-25           7.6           5   Jan 18, 2008
# 16018     2018-06-08           7.0        2491    Jun 8, 2018
# 16202     2018-09-10           7.1         142   Sep 21, 2018
# 16260     2010-01-01           5.0           1   Dec 24, 2003
#
#        production_budget  domestic_gross movie_year       net         ROI
# 15870           25000000        22486409       2017  -2513591  -11.178268
# 15923            2000000          347578       2015  -1652422 -475.410411
# 16018           10000000        44069456       2018  34069456   77.308547
# 16202            5000000         6352306       2018   1352306   21.288427
# 16260            5000000        34469210       2010  29469210   85.494301

# %%
final_df.drop(['release_date_x','movie_year'], axis=1, inplace=True)
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
final_df.head()
# Out:
#                      genres                            title region  \
# 23           Comedy,Mystery                    The Overnight     US
# 26  Adventure,Drama,Romance                      On the Road     US
# 27                   Horror                         Whiplash     US
# 31   Adventure,Comedy,Drama  The Secret Life of Walter Mitty     US
# 34       Action,Crime,Drama      A Walk Among the Tombstones     US
#
#     popularity  vote_average  vote_count release_date_y  production_budget  \
# 23       6.576           6.0         200   Jun 19, 2015             200000
# 26       8.919           5.6         518   Mar 22, 2013           25000000
# 27       6.298           7.9          94   Oct 10, 2014            3300000
# 31      10.743           7.1        4859   Dec 25, 2013           91000000
# 34      19.373           6.3        1685   Sep 19, 2014           28000000
#
#     domestic_gross       net          ROI
# 23         1109808    909808    81.978865
# 26          720828 -24279172 -3368.233753
# 27        13092006   9792006    74.793779
# 31        58236838 -32763162   -56.258484
# 34        26017685  -1982315    -7.619106

# %%
final_df.dtypes
# Out:
# genres                object
# title                 object
# region                object
# popularity           float64
# vote_average         float64
# vote_count             int64
# release_date_y        object
# production_budget      int64
# domestic_gross         int64
# net                    int64
# ROI                  float64
# dtype: object

# %%
final_df['release_date'] = final_df.release_date_y.apply(lambda x: pd.to_datetime(x).strftime('%m%d%Y'))
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_df.head()
# Out:
#                      genres                            title region  \
# 23           Comedy,Mystery                    The Overnight     US
# 26  Adventure,Drama,Romance                      On the Road     US
# 27                   Horror                         Whiplash     US
# 31   Adventure,Comedy,Drama  The Secret Life of Walter Mitty     US
# 34       Action,Crime,Drama      A Walk Among the Tombstones     US
#
#     popularity  vote_average  vote_count release_date_y  production_budget  \
# 23       6.576           6.0         200   Jun 19, 2015             200000
# 26       8.919           5.6         518   Mar 22, 2013           25000000
# 27       6.298           7.9          94   Oct 10, 2014            3300000
# 31      10.743           7.1        4859   Dec 25, 2013           91000000
# 34      19.373           6.3        1685   Sep 19, 2014           28000000
#
#     domestic_gross       net          ROI release_date
# 23         1109808    909808    81.978865     06192015
# 26          720828 -24279172 -3368.233753     03222013
# 27        13092006   9792006    74.793779     10102014
# 31        58236838 -32763162   -56.258484     12252013
# 34        26017685  -1982315    -7.619106     09192014

# %%
final_df.dtypes
# Out:
# genres                object
# title                 object
# region                object
# popularity           float64
# vote_average         float64
# vote_count             int64
# release_date_y        object
# production_budget      int64
# domestic_gross         int64
# net                    int64
# ROI                  float64
# release_date          object
# dtype: object

# %%
final_df.dtypes
# Out:
# genres                object
# title                 object
# region                object
# popularity           float64
# vote_average         float64
# vote_count             int64
# release_date_y        object
# production_budget      int64
# domestic_gross         int64
# net                    int64
# ROI                  float64
# release_date          object
# dtype: object

# %%
final_df['release_date'] = pd.to_datetime(final_df['release_date'], format='%m%d%Y')
# Out:
# /Users/sandrawelbeck/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_df.dtypes
# Out:
# genres                       object
# title                        object
# region                       object
# popularity                  float64
# vote_average                float64
# vote_count                    int64
# release_date_y               object
# production_budget             int64
# domestic_gross                int64
# net                           int64
# ROI                         float64
# release_date         datetime64[ns]
# dtype: object

# %%
# from datetime import datetime

# datetime.strptime(final_df['release_date'], '%d%m%Y')

# %%
# final_df['release_date'].astype('datetime64[ns]')
# final_df['release_date'] = pd.to_datetime(final_df['release_date'])
